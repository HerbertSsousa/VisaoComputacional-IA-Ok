# %%
# Importando a biblioteca OpenCV:
import cv2
# Importando o numpy (Numerical Python) para trabalhar com arrays
import numpy as np
# Importando o pacote pyplot do matplotlib
from matplotlib import pyplot as plt

# %%
# Instalando a biblioteca do YOLOv8
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 874.1/874.1 kB 5.5 MB/s eta 0:00:00
# ...

# %%
# Importando o pacote ultralytics
import ultralytics
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# Importando o pacote Pytorch
# Documentação: https://pytorch.org/

import torch

# %%
# Importando as demais bibliotecas
import cv2
from google.colab.patches import cv2_imshow

# %%
# Importando as demais bibliotecas
import cv2
import matplotlib.pyplot as plt
import os
from PIL import Image
from google.colab.patches import cv2_imshow

# %%
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='/content/advogados.png' save=True
# Out:
# ...
# 100% 6.25M/6.25M [00:00<00:00, 73.9MB/s]
# Ultralytics YOLOv8.2.100 🚀 Python-3.10.12 torch-2.4.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/advogados.png: 448x640 3 persons, 1 handbag, 3 ties, 1 book, 468.5ms
# Speed: 25.7ms preprocess, 468.5ms inference, 35.9ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
resultado = cv2.imread('/content/runs/detect/predict/advogados.png')
cv2_imshow(resultado)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>

# %%
# Detecção a partir da Imagem2:
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='/content/Imagem2.png' save=True
# Out:
# Ultralytics YOLOv8.2.100 🚀 Python-3.10.12 torch-2.4.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/Imagem2.png: 480x640 11 persons, 1 horse, 304.8ms
# Speed: 16.2ms preprocess, 304.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
image = Image.open('/content/Imagem2.png')
width, height = image.size
new_width = width * 2
new_height = height * 2
resized_image = image.resize((int(new_width), int(new_height)))
resized_image.save('/content/Imagem2.png')

#!yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='/content/Imagem2.png' save=True
resultado = cv2.imread('/content/runs/detect/predict2/Imagem2.png')
cv2_imshow(resultado)
# Out:
# <PIL.Image.Image image mode=RGB size=259x194>

# %%
#detcção de videos
# !yolo task=detect mode=predict model=yolov8m.pt conf=0.5 source='/content/video-fundo.mp4' save=true
# Out:
# ...
# 100% 49.7M/49.7M [00:00<00:00, 164MB/s]
# Ultralytics YOLOv8.2.100 🚀 Python-3.10.12 torch-2.4.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8m summary (fused): 218 layers, 25,886,080 parameters, 0 gradients, 78.9 GFLOPs
#
# video 1/1 (frame 1/240) /content/video-fundo.mp4: 384x640 4 boats, 1232.8ms
# video 1/1 (frame 2/240) /content/video-fundo.mp4: 384x640 4 boats, 1606.1ms
# video 1/1 (frame 3/240) /content/video-fundo.mp4: 384x640 4 boats, 1585.9ms
# video 1/1 (frame 4/240) /content/video-fundo.mp4: 384x640 4 boats, 1049.3ms
# video 1/1 (frame 5/240) /content/video-fundo.mp4: 384x640 4 boats, 1029.6ms
# video 1/1 (frame 6/240) /content/video-fundo.mp4: 384x640 5 boats, 1003.6ms
# video 1/1 (frame 7/240) /content/video-fundo.mp4: 384x640 5 boats, 1189.3ms
# video 1/1 (frame 8/240) /content/video-fundo.mp4: 384x640 5 boats, 1341.8ms
# video 1/1 (frame 9/240) /content/video-fundo.mp4: 384x640 5 boats, 969.0ms
# video 1/1 (frame 10/240) /content/video-fundo.mp4: 384x640 3 boats, 992.3ms
# ...

# %%
# !pip install inference-sdk pillow
# !pip install inference-sdk
# !pip install inference-sdk pillow matplotlib

# %%
# Importar o SDK de inferência e as bibliotecas necessárias
from inference_sdk import InferenceHTTPClient
from google.colab import files
from PIL import Image, ImageDraw
import matplotlib.pyplot as plt
import requests

# para analisar a imagem, baixe e escolha os arquivos que deseja procurar carros!


# Inicializar o cliente com a URL e a chave da API
CLIENT = InferenceHTTPClient(
    api_url="https://detect.roboflow.com",
    api_key="PH63YsNXfScM9AgIGGR5"
)

# Fazer o upload da imagem
uploaded = files.upload()
image_path = list(uploaded.keys())[0]

# Fazer a inferência na imagem enviada
result = CLIENT.infer(image_path, model_id="modelo-j8zfk/1")
print(result)

# Abrir a imagem carregada
image = Image.open(image_path)

# Criar um objeto de desenho
draw = ImageDraw.Draw(image)

# Se o resultado retornar previsões com caixas delimitadoras
if 'predictions' in result:
    for prediction in result['predictions']:
        # Obter as coordenadas da caixa delimitadora
        x = prediction['x']
        y = prediction['y']
        width = prediction['width']
        height = prediction['height']
        left = x - width / 2
        top = y - height / 2
        right = x + width / 2
        bottom = y + height / 2

        # Desenhar a caixa delimitadora na imagem
        draw.rectangle([left, top, right, bottom], outline="red", width=3)

        # Adicionar o label (nome do objeto) acima da caixa
        label = prediction['class']
        draw.text((left, top - 10), label, fill="red")

# Exibir a imagem com as previsões usando matplotlib
plt.figure(figsize=(8, 8))
plt.imshow(image)
plt.axis('off')
plt.show()
# Out:
#      <input type="file" id="files-5194341e-9785-4335-b875-c868689ee3ac" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5194341e-9785-4335-b875-c868689ee3ac">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
